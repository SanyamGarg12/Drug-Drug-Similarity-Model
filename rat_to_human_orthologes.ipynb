# %%
from pybiomart import Server
import pandas as pd

input_file = "MGI.xlsx" 
output_file = "human_MGI.csv" 

df = pd.read_excel(input_file, engine='openpyxl')

server = Server(host='http://www.ensembl.org')

dataset_rat = server.marts['ENSEMBL_MART_ENSEMBL'].datasets['rnorvegicus_gene_ensembl']

query = dataset_rat.query(
    attributes=['external_gene_name', 'hsapiens_homolog_associated_gene_name']
)

query.columns = ['Symbol', 'human_symbol']

df = df.merge(query, on='Symbol', how='left')

df.to_csv(output_file, index=False)

print(f"Conversion complete! Saved to {output_file}")
# Out:
# /home/prateek/miniconda3/lib/python3.12/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# Conversion complete! Saved to human_MGI.csv

# %%
df.head()
# Out:
#                   Type       MGI ID  Symbol  \
# 0  protein coding gene  MGI:3041203  Adgrd1
# 1  protein coding gene  MGI:2685213  Adgrg4
# 2  protein coding gene    MGI:87984    Akp3
# 3  protein coding gene    MGI:87984    Akp3
# 4  protein coding gene    MGI:87984    Akp3
#
#                                                 Name Chr      Start  \
# 0             adhesion G protein-coupled receptor D1   5  129173814
# 1             adhesion G protein-coupled receptor G4   X   55939594
# 2  alkaline phosphatase 3, intestine, not Mn requ...   1   87052695
# 3  alkaline phosphatase 3, intestine, not Mn requ...   1   87052695
# 4  alkaline phosphatase 3, intestine, not Mn requ...   1   87052695
#
#            End   Build Strand Best Match Type    Best Match  Match Score  \
# 0  129281663.0  GRCm39      +         Process  neurogenesis            4
# 1   56025719.0  GRCm39      +         Process  neurogenesis            4
# 2   87055634.0  GRCm39      +         Process  neurogenesis            4
# 3   87055634.0  GRCm39      +         Process  neurogenesis            4
# 4   87055634.0  GRCm39      +         Process  neurogenesis            4
#
#   human_symbol
# 0       ADGRD1
# 1       ADGRG4
# 2         ALPG
# 3         ALPP
# 4         ALPI

# %%
# check for null values in the 'human_symbol' column
null_values = df[df['human_symbol'].isnull()]
null_values
# Out:
#                      Type       MGI ID    Symbol  \
# 42    protein coding gene   MGI:109178     Fgf13
# 44    protein coding gene  MGI:1096383     Fgf15
# 54    protein coding gene  MGI:2685373     Gm527
# 55            lncRNA gene  MGI:5589890   Gm30731
# 62    protein coding gene  MGI:1915023      Kat8
# ...                   ...          ...       ...
# 2042  protein coding gene  MGI:2684056   Vmn2r81
# 2043  protein coding gene  MGI:3646522   Vmn2r82
# 2044  protein coding gene  MGI:3644559   Vmn2r83
# 2045  protein coding gene  MGI:3644483  Vmn2r120
# 2085  protein coding gene   MGI:109505     Xlr3b
#
#                                   Name Chr      Start          End   Build  \
# 42         fibroblast growth factor 13   X   58107505   58613431.0  GRCm39
# 44         fibroblast growth factor 15   7  144450269  144454690.0  GRCm39
# 54                  predicted gene 527  12   64964685   64971365.0  GRCm39
# 55               predicted gene, 30731   4   22490548   22493126.0  GRCm39
# 62       K(lysine) acetyltransferase 8   7  127511689  127525010.0  GRCm39
# ...                                ...  ..        ...          ...     ...
# 2042        vomeronasal 2, receptor 81  10   79083611   79130369.0  GRCm39
# 2043        vomeronasal 2, receptor 82  10   79192425   79232600.0  GRCm39
# 2044        vomeronasal 2, receptor 83  10   79304792   79327988.0  GRCm39
# 2045       vomeronasal 2, receptor 120  17   57815783   57852314.0  GRCm39
# 2085  X-linked lymphocyte-regulated 3B   X   72235813   72246536.0  GRCm39
#
#      Strand  Best Match Type  \
# 42        -          Process
# 44        +          Process
# 54        +          Process
# 55        +          Process
# 62        +          Process
# ...     ...              ...
# 2042      +  Subterm Process
# 2043      +  Subterm Process
# 2044      +  Subterm Process
# 2045      -  Subterm Process
# 2085      +  Subterm Process
#
#                                              Best Match  Match Score  \
# 42                                         neurogenesis            4
# 44                                         neurogenesis            4
# 54                                         neurogenesis            4
# 55                                         neurogenesis            4
# 62                                         neurogenesis            4
# ...                                                 ...          ...
# 2042              neuron differentiation (neurogenesis)            3
# 2043              neuron differentiation (neurogenesis)            3
# 2044              neuron differentiation (neurogenesis)            3
# 2045              neuron differentiation (neurogenesis)            3
# 2085  positive regulation of dendritic spine morphog...            3
#
#      human_symbol
# 42            NaN
# 44            NaN
# 54            NaN
# 55            NaN
# 62            NaN
# ...           ...
# 2042          NaN
# 2043          NaN
# 2044          NaN
# 2045          NaN
# 2085          NaN
#
# [145 rows x 13 columns]

# %%
import pandas as pd
from pybiomart import Server
from rapidfuzz import process

# Load the CSV file
df = pd.read_csv("human_MGI.csv")

# Step 1: Try re-querying BioMart for missing values
server = Server(host="http://www.ensembl.org")
dataset_rat = server.marts['ENSEMBL_MART_ENSEMBL'].datasets['rnorvegicus_gene_ensembl']

query = dataset_rat.query(
    attributes=["external_gene_name", "hsapiens_homolog_associated_gene_name"]
)
query.columns = ["Symbol", "human_symbol"]

# Merge to re-check any missing values
df = df.merge(query, on="Symbol", how="left", suffixes=("", "_biomart"))
df["human_symbol"] = df["human_symbol"].fillna(df["human_symbol_biomart"])
df.drop(columns=["human_symbol_biomart"], inplace=True)

# Step 2: Use fuzzy matching for remaining null values
human_gene_list = query["human_symbol"].dropna().unique()
fuzzy_converted = []  # Store converted gene pairs

def fuzzy_match(symbol):
    result = process.extractOne(symbol, human_gene_list)
    if result:
        match, score, _ = result
        if score > 80:
            fuzzy_converted.append((symbol, match, score))  # Store match details
            return match
    return None

df["human_symbol_fuzzy"] = df["Symbol"].apply(
    lambda x: fuzzy_match(x) if pd.isna(df.at[df[df["Symbol"] == x].index[0], "human_symbol"]) else None
)
df["human_symbol"] = df["human_symbol"].fillna(df["human_symbol_fuzzy"])
df.drop(columns=["human_symbol_fuzzy"], inplace=True)

# Print all fuzzy matches
if fuzzy_converted:
    print("\nFuzzy Matching Applied for the following genes:")
    for rat_gene, human_gene, score in fuzzy_converted:
        print(f"{rat_gene} → {human_gene} (Confidence: {score:.2f})")
# Out:
# Fuzzy Matching Applied for the following genes:
# C9orf72 → C9orf72 (Confidence: 100.00)

# %%
df.head()
# Out:
#                   Type       MGI ID  Symbol  \
# 0  protein coding gene  MGI:3041203  Adgrd1
# 1  protein coding gene  MGI:2685213  Adgrg4
# 2  protein coding gene    MGI:87984    Akp3
# 3  protein coding gene    MGI:87984    Akp3
# 4  protein coding gene    MGI:87984    Akp3
#
#                                                 Name Chr      Start  \
# 0             adhesion G protein-coupled receptor D1   5  129173814
# 1             adhesion G protein-coupled receptor G4   X   55939594
# 2  alkaline phosphatase 3, intestine, not Mn requ...   1   87052695
# 3  alkaline phosphatase 3, intestine, not Mn requ...   1   87052695
# 4  alkaline phosphatase 3, intestine, not Mn requ...   1   87052695
#
#            End   Build Strand Best Match Type    Best Match  Match Score  \
# 0  129281663.0  GRCm39      +         Process  neurogenesis            4
# 1   56025719.0  GRCm39      +         Process  neurogenesis            4
# 2   87055634.0  GRCm39      +         Process  neurogenesis            4
# 3   87055634.0  GRCm39      +         Process  neurogenesis            4
# 4   87055634.0  GRCm39      +         Process  neurogenesis            4
#
#   human_symbol
# 0       ADGRD1
# 1       ADGRG4
# 2         ALPG
# 3         ALPG
# 4         ALPG

# %%
df["human_symbol"].isna().sum()
# Out:
# 144

# %%
# !pip install chembl_webresource_client
# Out:
# Collecting chembl_webresource_client
#   Downloading chembl_webresource_client-0.10.9-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: urllib3 in /home/prateek/miniconda3/lib/python3.12/site-packages (from chembl_webresource_client) (2.2.2)
# Requirement already satisfied: requests>=2.18.4 in /home/prateek/miniconda3/lib/python3.12/site-packages (from chembl_webresource_client) (2.32.3)
# Requirement already satisfied: requests-cache~=1.2 in /home/prateek/miniconda3/lib/python3.12/site-packages (from chembl_webresource_client) (1.2.1)
# Collecting easydict (from chembl_webresource_client)
#   Downloading easydict-1.13-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/prateek/miniconda3/lib/python3.12/site-packages (from requests>=2.18.4->chembl_webresource_client) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/prateek/miniconda3/lib/python3.12/site-packages (from requests>=2.18.4->chembl_webresource_client) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/prateek/miniconda3/lib/python3.12/site-packages (from requests>=2.18.4->chembl_webresource_client) (2025.1.31)
# Requirement already satisfied: attrs>=21.2 in /home/prateek/miniconda3/lib/python3.12/site-packages (from requests-cache~=1.2->chembl_webresource_client) (24.2.0)
# Requirement already satisfied: cattrs>=22.2 in /home/prateek/miniconda3/lib/python3.12/site-packages (from requests-cache~=1.2->chembl_webresource_client) (24.1.3)
# Requirement already satisfied: platformdirs>=2.5 in /home/prateek/miniconda3/lib/python3.12/site-packages (from requests-cache~=1.2->chembl_webresource_client) (3.10.0)
# Requirement already satisfied: url-normalize>=1.4 in /home/prateek/miniconda3/lib/python3.12/site-packages (from requests-cache~=1.2->chembl_webresource_client) (2.2.0)
# Downloading chembl_webresource_client-0.10.9-py3-none-any.whl (55 kB)
# Downloading easydict-1.13-py3-none-any.whl (6.8 kB)
# Installing collected packages: easydict, chembl_webresource_client
# Successfully installed chembl_webresource_client-0.10.9 easydict-1.13

# %%
df = pd.read_csv("human_MGI.csv")
df.head()
# Out:
#                   Type       MGI ID  Symbol  \
# 0  protein coding gene  MGI:3041203  Adgrd1
# 1  protein coding gene  MGI:2685213  Adgrg4
# 2  protein coding gene    MGI:87984    Akp3
# 3  protein coding gene    MGI:87984    Akp3
# 4  protein coding gene    MGI:87984    Akp3
#
#                                                 Name Chr      Start  \
# 0             adhesion G protein-coupled receptor D1   5  129173814
# 1             adhesion G protein-coupled receptor G4   X   55939594
# 2  alkaline phosphatase 3, intestine, not Mn requ...   1   87052695
# 3  alkaline phosphatase 3, intestine, not Mn requ...   1   87052695
# 4  alkaline phosphatase 3, intestine, not Mn requ...   1   87052695
#
#            End   Build Strand Best Match Type    Best Match  Match Score  \
# 0  129281663.0  GRCm39      +         Process  neurogenesis            4
# 1   56025719.0  GRCm39      +         Process  neurogenesis            4
# 2   87055634.0  GRCm39      +         Process  neurogenesis            4
# 3   87055634.0  GRCm39      +         Process  neurogenesis            4
# 4   87055634.0  GRCm39      +         Process  neurogenesis            4
#
#   human_symbol
# 0       ADGRD1
# 1       ADGRG4
# 2         ALPG
# 3         ALPP
# 4         ALPI

# %%
from chembl_webresource_client.new_client import new_client

target = new_client.target
target_query = target.search('ALPG')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#   cross_references      organism                             pref_name  score  \
# 0               []  Homo sapiens   Alkaline phosphatase placental-like   16.0
# 1               []  Mus musculus  Alkaline phosphatase, placental-like   14.0
#
#    species_group_flag target_chembl_id  \
# 0               False       CHEMBL3402
# 1               False    CHEMBL3112374
#
#                                    target_components     target_type  tax_id
# 0  [{'accession': 'P10696', 'component_descriptio...  SINGLE PROTEIN    9606
# 1  [{'accession': 'P24823', 'component_descriptio...  SINGLE PROTEIN   10090

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL3402'

# %%
activity = new_client.activity
# for all targets calculate results
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)
df
# Out:
#                                            action_type activity_comment  \
# 0                                                 None             None
# 1                                                 None             None
# 2                                                 None             None
# 3                                                 None             None
# 4                                                 None             None
# ..                                                 ...              ...
# 716                                               None           Active
# 717  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 718  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 719  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 720  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#      activity_id activity_properties assay_chembl_id  \
# 0          33155                  []    CHEMBL640398
# 1          33157                  []    CHEMBL640398
# 2          34373                  []    CHEMBL640397
# 3          34374                  []    CHEMBL640398
# 4          39183                  []    CHEMBL640398
# ..           ...                 ...             ...
# 716      5776570                  []   CHEMBL1738497
# 717     24999546                  []   CHEMBL5232628
# 718     24999547                  []   CHEMBL5232628
# 719     24999548                  []   CHEMBL5232628
# 720     24999549                  []   CHEMBL5232628
#
#                                      assay_description assay_type  \
# 0    50% inhibition of human placental alkaline pho...          B
# 1    50% inhibition of human placental alkaline pho...          B
# 2    Concentration required for 50% inhibition of h...          B
# 3    50% inhibition of human placental alkaline pho...          B
# 4    50% inhibition of human placental alkaline pho...          B
# ..                                                 ...        ...
# 716  PUBCHEM_BIOASSAY: Luminescent assay for HTS di...          F
# 717  Inhibition of human germ cell alkaline phospha...          B
# 718  Inhibition of human germ cell alkaline phospha...          B
# 719  Inhibition of human germ cell alkaline phospha...          B
# 720  Inhibition of human germ cell alkaline phospha...          B
#
#     assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0                      None                   None  BAO_0000190  ...
# 1                      None                   None  BAO_0000190  ...
# 2                      None                   None  BAO_0000190  ...
# 3                      None                   None  BAO_0000190  ...
# 4                      None                   None  BAO_0000190  ...
# ..                      ...                    ...          ...  ...
# 716                    None                   None  BAO_0000190  ...
# 717                    None                   None  BAO_0000190  ...
# 718                    None                   None  BAO_0000190  ...
# 719                    None                   None  BAO_0000190  ...
# 720                    None                   None  BAO_0000190  ...
#
#     target_organism                     target_pref_name target_tax_id  \
# 0      Homo sapiens  Alkaline phosphatase placental-like          9606
# 1      Homo sapiens  Alkaline phosphatase placental-like          9606
# 2      Homo sapiens  Alkaline phosphatase placental-like          9606
# 3      Homo sapiens  Alkaline phosphatase placental-like          9606
# 4      Homo sapiens  Alkaline phosphatase placental-like          9606
# ..              ...                                  ...           ...
# 716    Homo sapiens  Alkaline phosphatase placental-like          9606
# 717    Homo sapiens  Alkaline phosphatase placental-like          9606
# 718    Homo sapiens  Alkaline phosphatase placental-like          9606
# 719    Homo sapiens  Alkaline phosphatase placental-like          9606
# 720    Homo sapiens  Alkaline phosphatase placental-like          9606
#
#     text_value  toid  type units    uo_units upper_value value
# 0         None  None   I50    mM  UO_0000065        None  0.28
# 1         None  None   I50    mM  UO_0000065        None   0.8
# 2         None  None   I50    mM  UO_0000065        None  0.97
# 3         None  None   I50    mM  UO_0000065        None  2.22
# 4         None  None   I50    mM  UO_0000065        None  10.0
# ..         ...   ...   ...   ...         ...         ...   ...
# 716       None  None  IC50    uM  UO_0000065        None  6.63
# 717       None  None  IC50    nM  UO_0000065        None  75.0
# 718       None  None  IC50    nM  UO_0000065        None  75.0
# 719       None  None  IC50    nM  UO_0000065        None  75.0
# 720       None  None  IC50    nM  UO_0000065        None  75.0
#
# [721 rows x 46 columns]

# %%
df["canonical_smiles"]
# Out:
# 0                    O=c1c2ccccc2nc2ccc(-c3nn[nH]n3)cn12
# 1                         O=C(O)c1cccn2c(=O)c3ccccc3nc12
# 2      CCCCc1cc2c(=O)cc(C(=O)O)[nH]c2c2c(=O)cc(C(=O)O...
# 3      CCCCc1cc2c(=O)cc(C(=O)O)[nH]c2c2c(=O)cc(C(=O)O...
# 4                               O=C(O)c1ccc2nccc(=O)n2c1
#                              ...
# 716    O=C(CSc1nnc(-c2ccncc2)n1-c1ccc(Cl)cc1)c1ccc(O)...
# 717              O=C(Nc1nc2ccccc2s1)c1cc(O)nc2ccc(O)cc12
# 718           COc1cc2c(C(=O)Nc3nc4ccccc4s3)cc(O)nc2cc1Cl
# 719             Cc1cc2nc(O)cc(C(=O)Nc3nc4ccccc4s3)c2cc1C
# 720            Cc1cc2c(C(=O)Nc3nc4ccccc4s3)cc(O)nc2cc1Cl
# Name: canonical_smiles, Length: 721, dtype: object

# %%
df['standard_value']
# Out:
# 0        280000.0
# 1        800000.0
# 2        970000.0
# 3       2220000.0
# 4      10000000.0
#           ...
# 716        6630.0
# 717          75.0
# 718          75.0
# 719          75.0
# 720          75.0
# Name: standard_value, Length: 721, dtype: object

# %%
# Out:
# Processing gene symbols:   0%|          | 3/1976 [00:00<01:31, 21.56it/s]
# Error processing ADGRG4: 'organism'
# Processing gene symbols:   0%|          | 6/1976 [00:00<01:19, 24.75it/s]
# Error processing ANKRD11: 'organism'
# Error processing ASCL1: 'organism'
# Error processing BRINP1: 'organism'
# Error processing BTBD1: 'organism'
# Processing gene symbols:   1%|          | 11/1976 [00:01<05:10,  6.33it/s]
# Error processing BTBD2: 'organism'
# Error processing BTBD3: 'organism'
# Processing gene symbols:   1%|          | 13/1976 [00:04<15:59,  2.05it/s]
# Error processing BTBD6: 'organism'
# Processing gene symbols:   1%|          | 14/1976 [00:06<22:05,  1.48it/s]
# Error processing CDK5RAP2: 'organism'
# Processing gene symbols:   1%|          | 15/1976 [00:07<27:09,  1.20it/s]
# Error processing CEP120: 'organism'
# Processing gene symbols:   1%|          | 16/1976 [00:09<31:29,  1.04it/s]
# Error processing CHAC1: 'organism'
# Processing gene symbols:   1%|          | 17/1976 [00:10<36:21,  1.11s/it]
# Error processing CLN5: 'organism'
# Processing gene symbols:   1%|          | 18/1976 [00:20<37:57,  1.16s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 31
#      29 # Get activity data (IC50 only)
#      30 res = activity.filter(target_chembl_id=target_id).filter(standard_type="IC50")
# ---> 31 res_list = list(res)
#      33 if res_list:
#      34     df_res = pd.DataFrame(res_list)
#
# File ~/miniconda3/lib/python3.12/site-packages/chembl_webresource_client/query_set.py:127, in QuerySet.__next__(self)
#     126 def __next__(self):
# --> 127     return self.next()
#
# File ~/miniconda3/lib/python3.12/site-packages/chembl_webresource_client/query_set.py:115, in QuerySet.next(self)
#     113     self.chunk = self.query.get_page()
#     114 if not self.chunk or self.current_index >= len(self.chunk):
# --> 115     self.chunk = self.query.next_page()
#     116     if not self.chunk:
#     117         raise StopIteration
#
# File ~/miniconda3/lib/python3.12/site-packages/chembl_webresource_client/url_query.py:434, in UrlQuery.next_page(self)
#     432 start = self.start
#     433 self.current_index = int(start + self.limit * (self.current_page + 1))
# --> 434 return self.get_page()
#
# File ~/miniconda3/lib/python3.12/site-packages/chembl_webresource_client/url_query.py:389, in UrlQuery.get_page(self)
#     387 data = self._prepare_url_params()
#     388 with self._get_session() as session:
# --> 389     res = session.post(self.base_url + '.' + self.frmt, json=data, timeout=self.timeout)
#     390 self.logger.info(res.url)
#     391 self.logger.info(data)
#
# File ~/miniconda3/lib/python3.12/site-packages/requests_cache/session.py:138, in CacheMixin.post(self, url, data, **kwargs)
#     137 def post(self, url: str, data=None, **kwargs) -> AnyResponse:  # type: ignore
# --> 138     return self.request('POST', url, data=data, **kwargs)
#
# File ~/miniconda3/lib/python3.12/site-packages/requests_cache/session.py:183, in CacheMixin.request(self, method, url, headers, expire_after, only_if_cached, refresh, force_refresh, *args, **kwargs)
#     181 headers = set_request_headers(headers, expire_after, only_if_cached, refresh, force_refresh)
#     182 with patch_form_boundary() if kwargs.get('files') else nullcontext():
# --> 183     return super().request(method, url, *args, headers=headers, **kwargs)
#
# File ~/miniconda3/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/miniconda3/lib/python3.12/site-packages/requests_cache/session.py:230, in CacheMixin.send(self, request, expire_after, only_if_cached, refresh, force_refresh, **kwargs)
#     228     response = self._resend(request, actions, cached_response, **kwargs)  # type: ignore
#     229 elif actions.send_request:
# --> 230     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#     231 else:
#     232     response = cached_response  # type: ignore  # Guaranteed to be non-None by this point
#
# File ~/miniconda3/lib/python3.12/site-packages/requests_cache/session.py:254, in CacheMixin._send_and_cache(self, request, actions, cached_response, **kwargs)
#     250 """Send a request and cache the response, unless disabled by settings or headers.
#     251 If applicable, also handle conditional requests.
#     252 """
#     253 request = actions.update_request(request)
# --> 254 response = super().send(request, **kwargs)
#     255 actions.update_from_response(response)
#     257 if not actions.skip_write:
#
# File ~/miniconda3/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/miniconda3/lib/python3.12/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/miniconda3/lib/python3.12/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File ~/miniconda3/lib/python3.12/site-packages/urllib3/connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463 try:
#     464     # Trigger any extra validation we need to do.
#     465     try:
# --> 466         self._validate_conn(conn)
#     467     except (SocketTimeout, BaseSSLError) as e:
#     468         self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File ~/miniconda3/lib/python3.12/site-packages/urllib3/connectionpool.py:1095, in HTTPSConnectionPool._validate_conn(self, conn)
#    1093 # Force connect early to allow us to validate the connection.
#    1094 if conn.is_closed:
# -> 1095     conn.connect()
#    1097 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#    1098 if not conn.is_verified and not conn.proxy_is_verified:
#
# File ~/miniconda3/lib/python3.12/site-packages/urllib3/connection.py:615, in HTTPSConnection.connect(self)
#     613 def connect(self) -> None:
#     614     sock: socket.socket | ssl.SSLSocket
# --> 615     self.sock = sock = self._new_conn()
#     616     server_hostname: str = self.host
#     617     tls_in_tls = False
#
# File ~/miniconda3/lib/python3.12/site-packages/urllib3/connection.py:196, in HTTPConnection._new_conn(self)
#     191 """Establish a socket connection and set nodelay settings on it.
#     192
#     193 :return: New socket connection.
#     194 """
#     195 try:
# --> 196     sock = connection.create_connection(
#     197         (self._dns_host, self.port),
#     198         self.timeout,
#     199         source_address=self.source_address,
#     200         socket_options=self.socket_options,
#     201     )
#     202 except socket.gaierror as e:
#     203     raise NameResolutionError(self.host, self, e) from e
#
# File ~/miniconda3/lib/python3.12/site-packages/urllib3/util/connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      71 if source_address:
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#      75 err = None
#
# KeyboardInterrupt:

# %%
dd = pd.read_csv("results/ALPG.csv")
# Out:
#                                            action_type activity_comment  \
# 0                                                  NaN              NaN
# 1                                                  NaN              NaN
# 2                                                  NaN              NaN
# 3                                                  NaN              NaN
# 4                                                  NaN              NaN
# ..                                                 ...              ...
# 716                                                NaN           Active
# 717  {'action_type': 'INHIBITOR', 'description': 'N...              NaN
# 718  {'action_type': 'INHIBITOR', 'description': 'N...              NaN
# 719  {'action_type': 'INHIBITOR', 'description': 'N...              NaN
# 720  {'action_type': 'INHIBITOR', 'description': 'N...              NaN
#
#      activity_id activity_properties assay_chembl_id  \
# 0          33155                  []    CHEMBL640398
# 1          33157                  []    CHEMBL640398
# 2          34373                  []    CHEMBL640397
# 3          34374                  []    CHEMBL640398
# 4          39183                  []    CHEMBL640398
# ..           ...                 ...             ...
# 716      5776570                  []   CHEMBL1738497
# 717     24999546                  []   CHEMBL5232628
# 718     24999547                  []   CHEMBL5232628
# 719     24999548                  []   CHEMBL5232628
# 720     24999549                  []   CHEMBL5232628
#
#                                      assay_description assay_type  \
# 0    50% inhibition of human placental alkaline pho...          B
# 1    50% inhibition of human placental alkaline pho...          B
# 2    Concentration required for 50% inhibition of h...          B
# 3    50% inhibition of human placental alkaline pho...          B
# 4    50% inhibition of human placental alkaline pho...          B
# ..                                                 ...        ...
# 716  PUBCHEM_BIOASSAY: Luminescent assay for HTS di...          F
# 717  Inhibition of human germ cell alkaline phospha...          B
# 718  Inhibition of human germ cell alkaline phospha...          B
# 719  Inhibition of human germ cell alkaline phospha...          B
# 720  Inhibition of human germ cell alkaline phospha...          B
#
#      assay_variant_accession  assay_variant_mutation bao_endpoint  ...  \
# 0                        NaN                     NaN  BAO_0000190  ...
# 1                        NaN                     NaN  BAO_0000190  ...
# 2                        NaN                     NaN  BAO_0000190  ...
# 3                        NaN                     NaN  BAO_0000190  ...
# 4                        NaN                     NaN  BAO_0000190  ...
# ..                       ...                     ...          ...  ...
# 716                      NaN                     NaN  BAO_0000190  ...
# 717                      NaN                     NaN  BAO_0000190  ...
# 718                      NaN                     NaN  BAO_0000190  ...
# 719                      NaN                     NaN  BAO_0000190  ...
# 720                      NaN                     NaN  BAO_0000190  ...
#
#     target_organism                     target_pref_name target_tax_id  \
# 0      Homo sapiens  Alkaline phosphatase placental-like          9606
# 1      Homo sapiens  Alkaline phosphatase placental-like          9606
# 2      Homo sapiens  Alkaline phosphatase placental-like          9606
# 3      Homo sapiens  Alkaline phosphatase placental-like          9606
# 4      Homo sapiens  Alkaline phosphatase placental-like          9606
# ..              ...                                  ...           ...
# 716    Homo sapiens  Alkaline phosphatase placental-like          9606
# 717    Homo sapiens  Alkaline phosphatase placental-like          9606
# 718    Homo sapiens  Alkaline phosphatase placental-like          9606
# 719    Homo sapiens  Alkaline phosphatase placental-like          9606
# 720    Homo sapiens  Alkaline phosphatase placental-like          9606
#
#     text_value toid  type units    uo_units upper_value  value
# 0          NaN  NaN   I50    mM  UO_0000065         NaN   0.28
# 1          NaN  NaN   I50    mM  UO_0000065         NaN   0.80
# 2          NaN  NaN   I50    mM  UO_0000065         NaN   0.97
# 3          NaN  NaN   I50    mM  UO_0000065         NaN   2.22
# 4          NaN  NaN   I50    mM  UO_0000065         NaN  10.00
# ..         ...  ...   ...   ...         ...         ...    ...
# 716        NaN  NaN  IC50    uM  UO_0000065         NaN   6.63
# 717        NaN  NaN  IC50    nM  UO_0000065         NaN  75.00
# 718        NaN  NaN  IC50    nM  UO_0000065         NaN  75.00
# 719        NaN  NaN  IC50    nM  UO_0000065         NaN  75.00
# 720        NaN  NaN  IC50    nM  UO_0000065         NaN  75.00
#
# [721 rows x 46 columns]

# %%
dd["canonical_smiles"]
# Out:
# 0                    O=c1c2ccccc2nc2ccc(-c3nn[nH]n3)cn12
# 1                         O=C(O)c1cccn2c(=O)c3ccccc3nc12
# 2      CCCCc1cc2c(=O)cc(C(=O)O)[nH]c2c2c(=O)cc(C(=O)O...
# 3      CCCCc1cc2c(=O)cc(C(=O)O)[nH]c2c2c(=O)cc(C(=O)O...
# 4                               O=C(O)c1ccc2nccc(=O)n2c1
#                              ...
# 716    O=C(CSc1nnc(-c2ccncc2)n1-c1ccc(Cl)cc1)c1ccc(O)...
# 717              O=C(Nc1nc2ccccc2s1)c1cc(O)nc2ccc(O)cc12
# 718           COc1cc2c(C(=O)Nc3nc4ccccc4s3)cc(O)nc2cc1Cl
# 719             Cc1cc2nc(O)cc(C(=O)Nc3nc4ccccc4s3)c2cc1C
# 720            Cc1cc2c(C(=O)Nc3nc4ccccc4s3)cc(O)nc2cc1Cl
# Name: canonical_smiles, Length: 721, dtype: object
